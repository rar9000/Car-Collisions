# %%
import pandas as pd
import geopandas
import os

# %%
zipcodes = geopandas.read_file("Jefferson_County_KY_ZIP_Codes.shp")
zipcodes
# Out:
#     OBJECTID ZIPCODE     SHAPEAREA       SHAPELEN  \
# 0          1   40203  8.608996e+07   76402.584655
# 1          2   40210  8.825244e+07   58504.651674
# 2          3   40059  3.342632e+08  102937.557822
# 3          4   40220  2.150630e+08   85234.904721
# 4          5   40041  3.513355e+06    8445.222310
# 5          6   40047  1.896746e+07   34240.551809
# 6          7   40242  8.403457e+06   13857.902515
# 7          8   40211  1.881935e+08   85713.716841
# 8          9   40215  9.079303e+07   65631.644556
# 9         10   40205  2.051036e+08   78836.120609
# 10        11   40218  2.379319e+08  127401.232670
# 11        12   40222  3.162957e+08  169049.790760
# 12        13   40223  3.591296e+08  147632.853069
# 13        14   40067  9.555427e+06   22478.406152
# 14        15   40177  3.187238e+07   33235.436478
# 15        16   40212  1.196774e+08   58372.694543
# 16        17   40214  4.230447e+08  150445.262025
# 17        18   40299  1.458310e+09  252695.711858
# ...

# %%
data = pd.read_csv("df1.csv")
coordinates = data[['Longitude', 'Latitude']]
coordinates
# Out:
#     Longitude   Latitude
# 0  -85.554810  38.301371
# 1  -85.695252  38.225175
# 2  -85.762779  38.223451
# 3  -85.816979  38.228913
# 4  -85.813590  38.239276
# 5  -85.793932  38.257962
# 6  -85.713534  38.136792
# 7  -85.706008  38.192689
# 8  -85.626108  38.219557
# 9  -85.605001  38.168968
# 10 -85.579603  38.134145

# %%
points = geopandas.GeoDataFrame(
    coordinates, geometry=geopandas.points_from_xy(coordinates.Longitude, coordinates.Latitude), crs="EPSG:4326")['geometry']

points
# Out:
# 0     POINT (-85.55481 38.30137)
# 1     POINT (-85.69525 38.22517)
# 2     POINT (-85.76278 38.22345)
# 3     POINT (-85.81698 38.22891)
# 4     POINT (-85.81359 38.23928)
# 5     POINT (-85.79393 38.25796)
# 6     POINT (-85.71353 38.13679)
# 7     POINT (-85.70601 38.19269)
# 8     POINT (-85.62611 38.21956)
# 9     POINT (-85.60500 38.16897)
# 10    POINT (-85.57960 38.13414)
# Name: geometry, dtype: geometry

# %%
points.iloc[10].within(zipcodes['geometry'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# Name: geometry, dtype: bool
